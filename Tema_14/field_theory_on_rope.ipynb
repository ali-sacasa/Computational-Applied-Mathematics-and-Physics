# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 from scipy.stats import norm
#
# ModuleNotFoundError: No module named 'numpy'

# %%
def laplacian_2d(phi, dx):
    return (np.roll(phi, 1, axis=0)+
        np.roll(phi, -1, axis=0)+
        np.roll(phi, 1, axis=1)+
        np.roll(phi, -1, axis=1)-
        4 * phi
    )/dx**2

# %%
N = 200
dx = 1.0/N
dt =0.05*dx

phi = np.ones((N, N))
pi=np.zeros_like(phi)

# Initial condition induce by a sine wave perturbation, such that,
for i in range(N):
    for j in range(N):
        if abs(j-N//2+20*np.sin(i/10))<2:
            phi[i, j]=-1

# %%
plt.ion()
for step in range(2000):
   
    phi, pi = evolve_2d(phi, pi, dx, dt)

    if step % 20 == 0:
        plt.clf()
        plt.imshow(phi, cmap="RdBu")
        plt.colorbar()
        plt.title(f"t = {step*dt:.2f}")
        plt.pause(0.01)
